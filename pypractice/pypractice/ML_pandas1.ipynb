# %%
import pandas as pd

# %%
df=pd.read_csv('covid.csv')

# %%
df.describe()
# Out:
#          Economy code Consumption shocks (% decline in consumption growth)  \
# count         24   24                                                 25
# unique        24   24                                                 24
# top     Pakistan  LAO                                                6.6
# freq           1    1                                                  2
#
#        Unnamed: 3 Investment shocks (% decline in investment growth)  \
# count          25                                                 25
# unique         24                                                 25
# top           9.9                                               7.14
# freq            2                                                  1
#
#        Unnamed: 5 Decline in tourism receipts (% of GDP) Unnamed: 7  \
# count          25                                     25         25
# unique         25                                     25         25
# ...

# %%
df.head(40)
# Out:
#                              Economy code  \
# 0                                NaN  NaN
# 1                         Bangladesh  BAN
# 2                             Bhutan  BTN
# 3                  Brunei Darussalam  BRN
# 4                           Cambodia  CAM
# 5                               Fiji  FIJ
# 6                   Hong Kong, China  HKG
# 7                              India  IND
# 8                          Indonesia  IDN
# 9                         Kazakhstan  KAZ
# 10                   Kyrgyz Republic  KGZ
# 11  Lao People's Democratic Republic  LAO
# 12                          Malaysia  MAL
# 13                          Maldives  MDV
# 14                          Mongolia  MON
# 15                             Nepal  NPL
# 16                          Pakistan  PAK
# 17        People's Republic of China  CHN
# 18                       Philippines  PHI
# 19                 Republic of Korea  KOR
# 20                         Singapore  SIN
# ...

# %%
# df[df['Average Stringency Index'<'50']].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-97be44e2094d> in <module>
# ...

# %%
df.head(7)
# Out:
#              Economy code  \
# 0                NaN  NaN
# 1         Bangladesh  BAN
# 2             Bhutan  BTN
# 3  Brunei Darussalam  BRN
# 4           Cambodia  CAM
# 5               Fiji  FIJ
# 6   Hong Kong, China  HKG
#
#   Consumption shocks (% decline in consumption growth)           Unnamed: 3  \
# 0                               Shorter- containment    Longer- containment
# 1                                                7.7                  11.55
# 2                                                6.6                    9.9
# 3                                               6.42                   9.64
# 4                                               4.27                    6.4
# 5                                               4.97                   7.46
# 6                                                5.2                    7.8
#
#   Investment shocks (% decline in investment growth)           Unnamed: 5  \
# ...

# %%
import pandas as pd
df=pd.read_csv('covid.csv')
df['Consumption shocks (% decline in consumption growth)'].sort_values()
# Out:
# 22                       2
# 24                    3.57
# 11                    3.67
# 14                    3.78
# 4                     4.27
# 19                     4.8
# 5                     4.97
# 8                        5
# 6                      5.2
# 17                    5.46
# 18                     6.2
# 15                    6.28
# 7                      6.4
# 3                     6.42
# 2                      6.6
# 23                     6.6
# 12                     6.7
# 16                    7.26
# 20                     7.3
# 13                    7.31
# 21                    7.33
# 9                     7.46
# 1                      7.7
# 10                    7.99
# 0     Shorter- containment
# Name: Consumption shocks (% decline in consumption growth), dtype: object

# %%
df['Consumption shocks (% decline in consumption growth)'].sort_values().value_counts()
# Out:
# 6.6                     2
# 6.28                    1
# 7.33                    1
# 3.67                    1
# 7.99                    1
# 2                       1
# 5.46                    1
# 3.78                    1
# 4.8                     1
# 5.2                     1
# 7.26                    1
# 6.4                     1
# 7.3                     1
# 6.2                     1
# 6.7                     1
# 4.97                    1
# 7.46                    1
# 6.42                    1
# 3.57                    1
# 4.27                    1
# 7.7                     1
# 5                       1
# 7.31                    1
# Shorter- containment    1
# Name: Consumption shocks (% decline in consumption growth), dtype: int64

# %%
df.head(5)
# Out:
#              Economy code  \
# 0                NaN  NaN
# 1         Bangladesh  BAN
# 2             Bhutan  BTN
# 3  Brunei Darussalam  BRN
# 4           Cambodia  CAM
#
#   Consumption shocks (% decline in consumption growth)           Unnamed: 3  \
# 0                               Shorter- containment    Longer- containment
# 1                                                7.7                  11.55
# 2                                                6.6                    9.9
# 3                                               6.42                   9.64
# 4                                               4.27                    6.4
#
#   Investment shocks (% decline in investment growth)           Unnamed: 5  \
# 0                               Shorter- containment  Longer- containment
# 1                                               12.1                18.15
# 2                                               9.57                14.35
# ...

# %%
df.dropna()
# Out:
#                              Economy code  \
# 1                         Bangladesh  BAN
# 2                             Bhutan  BTN
# 3                  Brunei Darussalam  BRN
# 4                           Cambodia  CAM
# 5                               Fiji  FIJ
# 6                   Hong Kong, China  HKG
# 7                              India  IND
# 8                          Indonesia  IDN
# 9                         Kazakhstan  KAZ
# 10                   Kyrgyz Republic  KGZ
# 11  Lao People's Democratic Republic  LAO
# 12                          Malaysia  MAL
# 13                          Maldives  MDV
# 14                          Mongolia  MON
# 15                             Nepal  NPL
# 16                          Pakistan  PAK
# 17        People's Republic of China  CHN
# 18                       Philippines  PHI
# 19                 Republic of Korea  KOR
# 20                         Singapore  SIN
# 21                         Sri Lanka  SRI
# ...

# %%
df.describe(include=['object','float'])
# Out:
#            Economy code Consumption shocks (% decline in consumption growth)  \
# count           24   24                                                 25
# unique          24   24                                                 24
# top     Kazakhstan  KAZ                                                6.6
# freq             1    1                                                  2
#
#        Unnamed: 3 Investment shocks (% decline in investment growth)  \
# count          25                                                 25
# unique         24                                                 25
# top           9.9                                               4.67
# freq            2                                                  1
#
#        Unnamed: 5 Decline in tourism receipts (% of GDP) Unnamed: 7  \
# count          25                                     25         25
# unique         25                                     25         25
# ...

# %%
newdf = df[df['Economy']=='India']

# %%
newdf
# Out:
#   Economy code Consumption shocks (% decline in consumption growth)  \
# 7   India  IND                                                6.4
#
#   Unnamed: 3 Investment shocks (% decline in investment growth) Unnamed: 5  \
# 7        9.6                                               10.9      16.35
#
#   Decline in tourism receipts (% of GDP) Unnamed: 7 Average Stringency Index  \
# 7                                   -0.6      -0.87                     86.8
#
#   Average Mobility
# 7            -52.9

# %%
newdf1=df[df['Economy']=="Bangladesh"]

# %%
newdf1
# Out:
#       Economy code Consumption shocks (% decline in consumption growth)  \
# 1  Bangladesh  BAN                                                7.7
#
#   Unnamed: 3 Investment shocks (% decline in investment growth) Unnamed: 5  \
# 1      11.55                                               12.1      18.15
#
#   Decline in tourism receipts (% of GDP) Unnamed: 7 Average Stringency Index  \
# 1                                  -0.07      -0.11                     92.5
#
#   Average Mobility
# 1            -56.6

# %%
B1=df[df['Economy']=="Bangladesh"]

# %%
B1
# Out:
#       Economy code Consumption shocks (% decline in consumption growth)  \
# 1  Bangladesh  BAN                                                7.7
#
#   Unnamed: 3 Investment shocks (% decline in investment growth) Unnamed: 5  \
# 1      11.55                                               12.1      18.15
#
#   Decline in tourism receipts (% of GDP) Unnamed: 7 Average Stringency Index  \
# 1                                  -0.07      -0.11                     92.5
#
#   Average Mobility
# 1            -56.6
