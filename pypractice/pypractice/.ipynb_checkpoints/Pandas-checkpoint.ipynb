# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv',encoding='ISO-8859-1')

# %%
df.shape
# Out:
# (10058, 6)

# %%
df
# Out:
#                                              description  \
# 0       Business status Alert Level 4: Fully operational
# 1       Business status Alert Level 4: Fully operational
# 2       Business status Alert Level 4: Fully operational
# 3       Business status Alert Level 4: Fully operational
# 4       Business status Alert Level 4: Fully operational
# ...                                                  ...
# 10053  Reasons why you expect COVID-19 pandemic to ch...
# 10054  Reasons why you expect COVID-19 pandemic to ch...
# 10055  Reasons why you expect COVID-19 pandemic to ch...
# 10056  Reasons why you expect COVID-19 pandemic to ch...
# 10057  Reasons why you expect COVID-19 pandemic to ch...
#
#                                industry  level             size line_code  \
# 0                                 total    0.0   619 employees  C0301.01
# 1                                 total    0.0  2049 employees  C0301.01
# ...

# %%
df.describe(include=['object','float'])
# Out:
#                                               description industry  \
# count                                                6909     6909
# unique                                                148       43
# top     Reasons why you expect COVID-19 pandemic to ch...    total
# freq                                                   47      735
# mean                                                  NaN      NaN
# std                                                   NaN      NaN
# min                                                   NaN      NaN
# 25%                                                   NaN      NaN
# 50%                                                   NaN      NaN
# 75%                                                   NaN      NaN
# max                                                   NaN      NaN
#
#               level   size line_code        value
# count   6909.000000   6909      6909   6909.00000
# unique          NaN      5       148          NaN
# ...

# %%
df[df['industry']=='Other services'].describe()
# Out:
#        level        value
# count  147.0   147.000000
# mean     1.0   315.877551
# std      0.0   352.185601
# min      1.0     0.000000
# 25%      1.0    70.500000
# 50%      1.0   150.000000
# 75%      1.0   468.000000
# max      1.0  1209.000000

# %%
df
# Out:
#                                              description  \
# 0       Business status Alert Level 4: Fully operational
# 1       Business status Alert Level 4: Fully operational
# 2       Business status Alert Level 4: Fully operational
# 3       Business status Alert Level 4: Fully operational
# 4       Business status Alert Level 4: Fully operational
# ...                                                  ...
# 10053  Reasons why you expect COVID-19 pandemic to ch...
# 10054  Reasons why you expect COVID-19 pandemic to ch...
# 10055  Reasons why you expect COVID-19 pandemic to ch...
# 10056  Reasons why you expect COVID-19 pandemic to ch...
# 10057  Reasons why you expect COVID-19 pandemic to ch...
#
#                                industry  level             size line_code  \
# 0                                 total    0.0   619 employees  C0301.01
# 1                                 total    0.0  2049 employees  C0301.01
# ...

# %%
df = pd.read_csv('covid.csv')

# %%
df
# Out:
#            SNo ObservationDate     Province/State  Country/Region  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 285302  285303      05-02-2021  Zaporizhia Oblast         Ukraine
# 285303  285304      05-02-2021            Zeeland     Netherlands
# 285304  285305      05-02-2021           Zhejiang  Mainland China
# 285305  285306      05-02-2021    Zhytomyr Oblast         Ukraine
# 285306  285307      05-02-2021       Zuid-Holland     Netherlands
#
#              Last Update  Confirmed  Deaths  Recovered
# 0        1/22/2020 17:00          1       0          0
# 1        1/22/2020 17:00         14       0          0
# ...

# %%
df.Confirmed.sort_values(ascending=False)
# Out:
# 284597    5605532
# 283833    5597295
# 283069    5571804
# 282305    5547670
# 281541    5521227
#            ...
# 131151          0
# 56336           0
# 17486           0
# 190430          0
# 147238    -302844
# Name: Confirmed, Length: 285307, dtype: int64

# %%
df.sort_values(['Confirmed'],ascending=False).unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-924afb8fa229> in <module>
# ----> 1 df.sort_values(['Confirmed'],ascending=False).unique()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
#filtering 
df['Country/Region'].value_counts().sort_values()
# Out:
# North Ireland          1
# Cape Verde             1
# St. Martin             1
# Channel Islands        1
#  Azerbaijan            1
#                    ...
# India              12183
# Mainland China     14894
# Japan              16736
# US                 25174
# Russia             28010
# Name: Country/Region, Length: 228, dtype: int64

# %%
newdf = df[df['Country/Region']=='India']

# %%
newdf
# Out:
#            SNo ObservationDate Province/State Country/Region  \
# 438        439      01/30/2020            NaN          India
# 500        501      01/31/2020            NaN          India
# 557        558      02-01-2020            NaN          India
# 618        619      02-02-2020            NaN          India
# 684        685      02-03-2020            NaN          India
# ...        ...             ...            ...            ...
# 285229  285230      05-02-2021        Tripura          India
# 285244  285245      05-02-2021        Unknown          India
# 285255  285256      05-02-2021  Uttar Pradesh          India
# 285256  285257      05-02-2021    Uttarakhand          India
# 285284  285285      05-02-2021    West Bengal          India
#
#                 Last Update  Confirmed  Deaths  Recovered
# 438           1/30/20 16:00          1       0          0
# 500         1/31/2020 23:59          1       0          0
# ...

# %%
df[(df['Country/Region']=='India') | (df['Country/Region']=='France')]
# Out:
#            SNo ObservationDate     Province/State Country/Region  \
# 126        127      01/24/2020                NaN         France
# 168        169      01/25/2020                NaN         France
# 215        216      01/26/2020                NaN         France
# 263        264      01/27/2020                NaN         France
# 315        316      01/28/2020                NaN         France
# ...        ...             ...                ...            ...
# 285244  285245      05-02-2021            Unknown          India
# 285255  285256      05-02-2021      Uttar Pradesh          India
# 285256  285257      05-02-2021        Uttarakhand          India
# 285281  285282      05-02-2021  Wallis and Futuna         France
# 285284  285285      05-02-2021        West Bengal          India
#
#              Last Update  Confirmed  Deaths  Recovered
# 126        1/24/20 17:00          2       0          0
# 168        1/25/20 17:00          3       0          0
# ...

# %%
df[df['Country/Region'].isin(['India','France'])]
# Out:
#            SNo ObservationDate     Province/State Country/Region  \
# 126        127      01/24/2020                NaN         France
# 168        169      01/25/2020                NaN         France
# 215        216      01/26/2020                NaN         France
# 263        264      01/27/2020                NaN         France
# 315        316      01/28/2020                NaN         France
# ...        ...             ...                ...            ...
# 285244  285245      05-02-2021            Unknown          India
# 285255  285256      05-02-2021      Uttar Pradesh          India
# 285256  285257      05-02-2021        Uttarakhand          India
# 285281  285282      05-02-2021  Wallis and Futuna         France
# 285284  285285      05-02-2021        West Bengal          India
#
#              Last Update  Confirmed  Deaths  Recovered
# 126        1/24/20 17:00          2       0          0
# 168        1/25/20 17:00          3       0          0
# ...

# %%
df.to_csv('final_df.csv')

# %%
df.columns
# Out:
# Index(['SNo', 'ObservationDate', 'Province/State', 'Country/Region',
#        'Last Update', 'Confirmed', 'Deaths', 'Recovered'],
#       dtype='object')

# %%
df_sub = pd.DataFrame(df,columns=['Confirmed', 'Deaths', 'Recovered'])

# %%
df_sub.head(10)
# Out:
#    Confirmed  Deaths  Recovered
# 0          1       0          0
# 1         14       0          0
# 2          6       0          0
# 3          1       0          0
# 4          0       0          0
# 5         26       0          0
# 6          2       0          0
# 7          1       0          0
# 8          4       0          0
# 9          1       0          0

# %%
del df_sub['Recovered']

# %%
df_sub
# Out:
#         Confirmed  Deaths
# 0               1       0
# 1              14       0
# 2               6       0
# 3               1       0
# 4               0       0
# ...           ...     ...
# 285302      96531    1919
# 285303      26045     233
# 285304       1344       1
# 285305      84641    1597
# 285306     359327    4138
#
# [285307 rows x 2 columns]

# %%
df.rename({'Province/State':'state','Country/Region':'Country'},axis=1,inplace=True)

# %%
len(df['state'].unique())
# Out:
# 738

# %%
df['state'].value_counts()
# Out:
# Unknown                         3799
# Amazonas                        1028
# Diamond Princess cruise ship     870
# Grand Princess                   828
# Punjab                           654
#                                 ...
# Harrison County, KY                1
# Wuhan Evacuee                      1
# Travis, CA                         1
# External territories               1
# Johnson County, IA                 1
# Name: state, Length: 737, dtype: int64

# %%
df.groupby('Country').sum().nlargest(100,'Confirmed')
# Out:
#                   SNo   Confirmed     Deaths   Recovered
# Country
# US         3163365772  5160429560  107452695   503370956
# India      1949718166  2561168608   37005858  2328844877
# Brazil     1443626758  2231591502   60861917  1940567667
# Russia     4405030644   798673069   15286961   669086949
# France      627719646   698815739   19812860    59193931
# ...               ...         ...        ...         ...
# Sri Lanka    54458891    11763716      64633    10495459
# Zambia       54343180    10991488     171894    10174297
# Finland      54418645    10672499     180847     7305672
# Uruguay      54364059    10554674     118485     8583882
# Estonia      54377662    10411493     101945     8037781
#
# [100 rows x 4 columns]

# %%
90*10
# Out:
# 900

# %%
df['India'].str.replace
# Out:
#            SNo ObservationDate              state         Country  \
# 0            1      01/22/2020              Anhui  Mainland China
# 1            2      01/22/2020            Beijing  Mainland China
# 2            3      01/22/2020          Chongqing  Mainland China
# 3            4      01/22/2020             Fujian  Mainland China
# 4            5      01/22/2020              Gansu  Mainland China
# ...        ...             ...                ...             ...
# 285302  285303      05-02-2021  Zaporizhia Oblast         Ukraine
# 285303  285304      05-02-2021            Zeeland     Netherlands
# 285304  285305      05-02-2021           Zhejiang  Mainland China
# 285305  285306      05-02-2021    Zhytomyr Oblast         Ukraine
# 285306  285307      05-02-2021       Zuid-Holland     Netherlands
#
#              Last Update  Confirmed  Deaths  Recovered
# 0        1/22/2020 17:00          1       0          0
# 1        1/22/2020 17:00         14       0          0
# ...
