# %%
import pandas as pd

# %%
df=pd.read_csv('covid.csv')

# %%
df.head()
# Out:
#              Economy code  \
# 0                NaN  NaN
# 1         Bangladesh  BAN
# 2             Bhutan  BTN
# 3  Brunei Darussalam  BRN
# 4           Cambodia  CAM
#
#   Consumption shocks (% decline in consumption growth)           Unnamed: 3  \
# 0                               Shorter- containment    Longer- containment
# 1                                                7.7                  11.55
# 2                                                6.6                    9.9
# 3                                               6.42                   9.64
# 4                                               4.27                    6.4
#
#   Investment shocks (% decline in investment growth)           Unnamed: 5  \
# 0                               Shorter- containment  Longer- containment
# 1                                               12.1                18.15
# 2                                               9.57                14.35
# ...

# %%
df.tail()
# Out:
#          Economy code Consumption shocks (% decline in consumption growth)  \
# 20     Singapore  SIN                                                7.3
# 21     Sri Lanka  SRI                                               7.33
# 22  Taipei,China  TAP                                                  2
# 23      Thailand  THA                                                6.6
# 24      Viet Nam  VIE                                               3.57
#
#    Unnamed: 3 Investment shocks (% decline in investment growth) Unnamed: 5  \
# 20      10.95                                                7.7      11.55
# 21      10.99                                              11.78      17.67
# 22          3                                                2.7       4.05
# 23        9.9                                                8.9      13.35
# 24       5.35                                               5.13        7.7
#
# ...

# %%
df.tail(2)
# Out:
#      Economy code Consumption shocks (% decline in consumption growth)  \
# 23  Thailand  THA                                                6.6
# 24  Viet Nam  VIE                                               3.57
#
#    Unnamed: 3 Investment shocks (% decline in investment growth) Unnamed: 5  \
# 23        9.9                                                8.9      13.35
# 24       5.35                                               5.13        7.7
#
#    Decline in tourism receipts (% of GDP) Unnamed: 7 Average Stringency Index  \
# 23                                  -7.22     -10.45                     71.2
# 24                                   -2.3      -3.32                     75.5
#
#    Average Mobility
# 23            -33.7
# 24            -31.2

# %%
df.dtypes
# Out:
# Economy                                                 object
# code                                                    object
# Consumption shocks (% decline in consumption growth)    object
# Unnamed: 3                                              object
# Investment shocks (% decline in investment growth)      object
# Unnamed: 5                                              object
# Decline in tourism receipts (% of GDP)                  object
# Unnamed: 7                                              object
# Average Stringency Index                                object
# Average Mobility                                        object
# dtype: object

# %%
df['Average Mobility']
# Out:
# 0         NaN
# 1       -56.6
# 2     no data
# 3     no data
# 4       -33.7
# 5       -33.4
# 6       -18.8
# 7       -52.9
# 8       -32.5
# 9       -40.8
# 10      -59.3
# 11        -42
# 12      -51.8
# 13    no data
# 14       -0.5
# 15        -62
# 16      -44.6
# 17    no data
# 18      -63.2
# 19       -4.2
# 20      -25.9
# 21      -66.4
# 22       -6.9
# 23      -33.7
# 24      -31.2
# Name: Average Mobility, dtype: object

# %%
df['Consumption shocks (% decline in consumption growth)']
# Out:
# 0     Shorter- containment
# 1                      7.7
# 2                      6.6
# 3                     6.42
# 4                     4.27
# 5                     4.97
# 6                      5.2
# 7                      6.4
# 8                        5
# 9                     7.46
# 10                    7.99
# 11                    3.67
# 12                     6.7
# 13                    7.31
# 14                    3.78
# 15                    6.28
# 16                    7.26
# 17                    5.46
# 18                     6.2
# 19                     4.8
# 20                     7.3
# 21                    7.33
# 22                       2
# 23                     6.6
# 24                    3.57
# Name: Consumption shocks (% decline in consumption growth), dtype: object

# %%
type(df['Unnamed: 3'])
# Out:
# pandas.core.series.Series

# %%
df.sum()
# Out:
# Series([], dtype: float64)

# %%
df.isnull().sum()
# Out:
# Economy                                                 1
# code                                                    1
# Consumption shocks (% decline in consumption growth)    0
# Unnamed: 3                                              0
# Investment shocks (% decline in investment growth)      0
# Unnamed: 5                                              0
# Decline in tourism receipts (% of GDP)                  0
# Unnamed: 7                                              0
# Average Stringency Index                                1
# Average Mobility                                        1
# dtype: int64

# %%
df.isnull()
# Out:
#     Economy   code  Consumption shocks (% decline in consumption growth)  \
# 0      True   True                                              False
# 1     False  False                                              False
# 2     False  False                                              False
# 3     False  False                                              False
# 4     False  False                                              False
# 5     False  False                                              False
# 6     False  False                                              False
# 7     False  False                                              False
# 8     False  False                                              False
# 9     False  False                                              False
# 10    False  False                                              False
# 11    False  False                                              False
# ...

# %%
df['Institute']="scooden"

# %%
df
# Out:
#                              Economy code  \
# 0                                NaN  NaN
# 1                         Bangladesh  BAN
# 2                             Bhutan  BTN
# 3                  Brunei Darussalam  BRN
# 4                           Cambodia  CAM
# 5                               Fiji  FIJ
# 6                   Hong Kong, China  HKG
# 7                              India  IND
# 8                          Indonesia  IDN
# 9                         Kazakhstan  KAZ
# 10                   Kyrgyz Republic  KGZ
# 11  Lao People's Democratic Republic  LAO
# 12                          Malaysia  MAL
# 13                          Maldives  MDV
# 14                          Mongolia  MON
# 15                             Nepal  NPL
# 16                          Pakistan  PAK
# 17        People's Republic of China  CHN
# 18                       Philippines  PHI
# 19                 Republic of Korea  KOR
# 20                         Singapore  SIN
# ...

# %%
df.drop(columns='Institute',axis=1,inplace=True)

# %%
df
# Out:
#                              Economy code  \
# 0                                NaN  NaN
# 1                         Bangladesh  BAN
# 2                             Bhutan  BTN
# 3                  Brunei Darussalam  BRN
# 4                           Cambodia  CAM
# 5                               Fiji  FIJ
# 6                   Hong Kong, China  HKG
# 7                              India  IND
# 8                          Indonesia  IDN
# 9                         Kazakhstan  KAZ
# 10                   Kyrgyz Republic  KGZ
# 11  Lao People's Democratic Republic  LAO
# 12                          Malaysia  MAL
# 13                          Maldives  MDV
# 14                          Mongolia  MON
# 15                             Nepal  NPL
# 16                          Pakistan  PAK
# 17        People's Republic of China  CHN
# 18                       Philippines  PHI
# 19                 Republic of Korea  KOR
# 20                         Singapore  SIN
# ...

# %%
dfnew=df.drop(columns="Average Stringency Index",axis=1)

# %%
df
# Out:
#                              Economy code  \
# 0                                NaN  NaN
# 1                         Bangladesh  BAN
# 2                             Bhutan  BTN
# 3                  Brunei Darussalam  BRN
# 4                           Cambodia  CAM
# 5                               Fiji  FIJ
# 6                   Hong Kong, China  HKG
# 7                              India  IND
# 8                          Indonesia  IDN
# 9                         Kazakhstan  KAZ
# 10                   Kyrgyz Republic  KGZ
# 11  Lao People's Democratic Republic  LAO
# 12                          Malaysia  MAL
# 13                          Maldives  MDV
# 14                          Mongolia  MON
# 15                             Nepal  NPL
# 16                          Pakistan  PAK
# 17        People's Republic of China  CHN
# 18                       Philippines  PHI
# 19                 Republic of Korea  KOR
# 20                         Singapore  SIN
# ...

# %%
dfnew
# Out:
#                              Economy code  \
# 0                                NaN  NaN
# 1                         Bangladesh  BAN
# 2                             Bhutan  BTN
# 3                  Brunei Darussalam  BRN
# 4                           Cambodia  CAM
# 5                               Fiji  FIJ
# 6                   Hong Kong, China  HKG
# 7                              India  IND
# 8                          Indonesia  IDN
# 9                         Kazakhstan  KAZ
# 10                   Kyrgyz Republic  KGZ
# 11  Lao People's Democratic Republic  LAO
# 12                          Malaysia  MAL
# 13                          Maldives  MDV
# 14                          Mongolia  MON
# 15                             Nepal  NPL
# 16                          Pakistan  PAK
# 17        People's Republic of China  CHN
# 18                       Philippines  PHI
# 19                 Republic of Korea  KOR
# 20                         Singapore  SIN
# ...

# %%
df123=df.copy()

# %%
df123
# Out:
#                              Economy code  \
# 0                                NaN  NaN
# 1                         Bangladesh  BAN
# 2                             Bhutan  BTN
# 3                  Brunei Darussalam  BRN
# 4                           Cambodia  CAM
# 5                               Fiji  FIJ
# 6                   Hong Kong, China  HKG
# 7                              India  IND
# 8                          Indonesia  IDN
# 9                         Kazakhstan  KAZ
# 10                   Kyrgyz Republic  KGZ
# 11  Lao People's Democratic Republic  LAO
# 12                          Malaysia  MAL
# 13                          Maldives  MDV
# 14                          Mongolia  MON
# 15                             Nepal  NPL
# 16                          Pakistan  PAK
# 17        People's Republic of China  CHN
# 18                       Philippines  PHI
# 19                 Republic of Korea  KOR
# 20                         Singapore  SIN
# ...

# %%
df.dropna()
# Out:
#                              Economy code  \
# 1                         Bangladesh  BAN
# 2                             Bhutan  BTN
# 3                  Brunei Darussalam  BRN
# 4                           Cambodia  CAM
# 5                               Fiji  FIJ
# 6                   Hong Kong, China  HKG
# 7                              India  IND
# 8                          Indonesia  IDN
# 9                         Kazakhstan  KAZ
# 10                   Kyrgyz Republic  KGZ
# 11  Lao People's Democratic Republic  LAO
# 12                          Malaysia  MAL
# 13                          Maldives  MDV
# 14                          Mongolia  MON
# 15                             Nepal  NPL
# 16                          Pakistan  PAK
# 17        People's Republic of China  CHN
# 18                       Philippines  PHI
# 19                 Republic of Korea  KOR
# 20                         Singapore  SIN
# 21                         Sri Lanka  SRI
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/Admin/Desktop/data.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0         A         B         C         D
# 0            0 -1.557181  0.373416  1.040685 -0.648513
# 1            1 -0.835872 -0.005259  0.502099 -0.956839
# 2            2 -0.257153  2.638228 -0.535731 -1.069443
# 3            3 -0.505502 -0.339260  0.602622 -1.420995
# 4            4  1.366398 -0.368296  0.642091  1.609680
# 5            5 -1.350101  0.210097 -0.743280  0.035729
# 6            6 -0.621305 -0.620733  0.141429 -1.831875
# 7            7 -0.670370 -0.379230  1.950228 -0.487202
# 8            8 -1.360577  0.044675 -0.576289  0.998686
# 9            9 -0.120302 -0.146491 -0.420956  1.412786
# 10          10  0.216936  0.398267  0.342519  0.387263
# 11          11  0.567832 -2.023668 -0.315318 -0.064349
# 12          12 -0.161148 -0.118924 -1.226679 -0.932540
# 13          13 -1.063620  0.041304 -1.037695  0.628520
# 14          14  0.912931  0.848745 -1.215276 -0.024202
# 15          15 -0.661489 -1.543994 -0.452754 -1.589521
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0          A          B          C          D
# count    50.00000  50.000000  50.000000  50.000000  50.000000
# mean     24.50000   0.020103  -0.123273  -0.044716   0.059140
# std      14.57738   1.139660   0.845836   0.848863   0.966854
# min       0.00000  -2.085251  -2.023668  -1.890289  -1.831875
# 25%      12.25000  -0.677750  -0.608653  -0.582724  -0.622080
# 50%      24.50000  -0.090116   0.000591  -0.215810  -0.091596
# 75%      36.75000   0.578342   0.361622   0.493181   0.813681
# max      49.00000   2.762885   2.638228   1.950228   1.983037

# %%
df.shape
# Out:
# (50, 5)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'A', 'B', 'C', 'D'], dtype='object')

# %%
df.rename({"A":"First","B":"Second"},axis=1,inplace=True)

# %%
df
# Out:
#     Unnamed: 0     First    Second         C         D
# 0            0 -1.557181  0.373416  1.040685 -0.648513
# 1            1 -0.835872 -0.005259  0.502099 -0.956839
# 2            2 -0.257153  2.638228 -0.535731 -1.069443
# 3            3 -0.505502 -0.339260  0.602622 -1.420995
# 4            4  1.366398 -0.368296  0.642091  1.609680
# 5            5 -1.350101  0.210097 -0.743280  0.035729
# 6            6 -0.621305 -0.620733  0.141429 -1.831875
# 7            7 -0.670370 -0.379230  1.950228 -0.487202
# 8            8 -1.360577  0.044675 -0.576289  0.998686
# 9            9 -0.120302 -0.146491 -0.420956  1.412786
# 10          10  0.216936  0.398267  0.342519  0.387263
# 11          11  0.567832 -2.023668 -0.315318 -0.064349
# 12          12 -0.161148 -0.118924 -1.226679 -0.932540
# 13          13 -1.063620  0.041304 -1.037695  0.628520
# 14          14  0.912931  0.848745 -1.215276 -0.024202
# 15          15 -0.661489 -1.543994 -0.452754 -1.589521
# ...

# %%
df['First'].describe()
# Out:
# count    50.000000
# mean      0.020103
# std       1.139660
# min      -2.085251
# 25%      -0.677750
# 50%      -0.090116
# 75%       0.578342
# max       2.762885
# Name: First, dtype: float64

# %%
df.describe(include=['float64','object'])
# Out:
#            First     Second          C          D
# count  50.000000  50.000000  50.000000  50.000000
# mean    0.020103  -0.123273  -0.044716   0.059140
# std     1.139660   0.845836   0.848863   0.966854
# min    -2.085251  -2.023668  -1.890289  -1.831875
# 25%    -0.677750  -0.608653  -0.582724  -0.622080
# 50%    -0.090116   0.000591  -0.215810  -0.091596
# 75%     0.578342   0.361622   0.493181   0.813681
# max     2.762885   2.638228   1.950228   1.983037
